# %%
#### Loads relevent python libraries ####
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as c
import scipy.fftpack as fft
import scipy.ndimage as ndi
import scipy as sp
from PIL import Image
from scipy.optimize import curve_fit
from matplotlib.ticker import MultipleLocator
import matplotlib.image as mpimg
import csv

# Alters font size
plt.rcParams.update({'font.size':12})

def sine(values, A, w, p, bg):
    return A*np.sin(values*w+p)+bg

def cubic(values,a,l,k,m,c):
    return a*values**4+l*values**3+k*values**2+m*values+c

def both(values, a, l, k, m, c, A, w, p):
    return a*values**4+l*values**3+k*values**2+m*values+c+A*np.sin(values*w+p)

def line(values, m, c):
    return values*m + c

# %%
#Load cone scan

fields = [0,20,40,60,80,100,120,140,160,180,200]
scans = [20,22,24,25,27,28,29,30,31,32,33]
lists = []
pxs = []
errs = []
ln = 19

for i in np.arange(0,len(scans),1):
    with open('line_'+str(scans[i])+'.csv', 'r') as f:
        cone = list(csv.reader(f, delimiter=';'))
    cone = np.array(cone[1:], dtype=np.float)
    cone = np.rot90(cone)
    lists.append(cone[0][4:45])
    cone_pxs = np.arange(0,len(cone[0][4:45]),1)
    err = np.sqrt(cone[0][4:45])
    pxs.append(cone_pxs)
    errs.append(err)

# %%
#Fitting line scan

pms1 = []
arrays1 = []
fits1 = []
lfits1 = []
lpxs = []

for i in np.arange(0,len(lists),1):
    pm, array = curve_fit(cubic, pxs[i], lists[i], p0=(1,1,1,1,9000), sigma = errs[i], absolute_sigma=True, maxfev=10000)
    fit = cubic(pxs[i],*pm)
    lpx = np.linspace(0,len(pxs[i])-1,1000)
    lpxs.append(lpx)
    lfit = cubic(lpx,*pm)
    pms1.append(pm)
    arrays1.append(array)
    fits1.append(fit)
    lfits1.append(lfit)

# %%
pms2 = []
arrays2 = []
fits2 = []

p0s = ([-5.09578448e+02,  1.09726462e+00, -3.42606315e+00, 0],
[-3.65033883e+02,  1.39747414e+00, -1.07108413e-01, 0],
[2.52858768e+02,  1.39729114e+00, -8.64319828e-01, 0],
[-2.35584719e+02,  1.41794476e+00, -5.80492958e+00, 0],
[-3.69539740e+02,  1.39204648e+00, -2.34702428e+00, 0],
[-3.77691407e+02,  1.41227605e+00, -1.18473775e+00, 0],
[-3.54619884e+02,  1.40202577e+00, -2.21506448e+00, 0],
[-3.05514093e+02,  1.38886519e+00, -2.64779689e+00, 0],
[1.72251938e+02,  1.32824638e+00, -5.20270560e-02, 0],
[-2.19063511e+02,  1.42531031e+00, -1.66501558e+00, 0],
[1.41071463e+02,  1.32859173e+00, -2.50263643e-01, 0])


lens1 = []
As1 = []

for i in np.arange(0,len(lists),1):
    pm, array = curve_fit(sine, pxs[i], lists[i]-fits1[i], p0=p0s[i], absolute_sigma=True, maxfev=10000)
    fit = sine(pxs[i],*pm)
    pms2.append(pm)
    arrays2.append(array)
    fits2.append(fit)
    lens1.append(pm[1])
    As1.append(abs(pm[0]))

# %%
pms3 = []
arrays3 = []
fits3 = []
lfits3 = []
lens2 = []
As2 = []
lams2 = []

elist = []
elist2 = []


p0s = ([4.33e-03, -4.86e-01,  2.41e+01,  5.21e+02, 9.35e+04, -5.80e+02,  1.09e+00,  1.01e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [ 1.08e-02, -1.54e+00,  8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00])

for i in np.arange(0,len(lists),1):
    pm, array = curve_fit(both, pxs[i], lists[i], p0=p0s[i], sigma = errs[i], absolute_sigma=True, maxfev=10000)
    fit = both(pxs[i],*pm)
    lfit = both(lpxs[i],*pm)

    pms3.append(pm)
    arrays3.append(array)
    fits3.append(fit)
    lfits3.append(lfit)
    lens2.append(30*np.pi/pm[6])
    As2.append(abs(pm[5]))
    lams2.append(30*np.pi/pm[6])
    print(pm)
  
    elist.append(np.sqrt(np.diag(array))[5])
    elist2.append(30*np.sqrt(np.diag(array))[6])


lams2[0] = 67.496516273
print(lams2)


#print(elist)

plt.figure()
plt.plot(pxs[0],lists[0],marker='o',ls='')
plt.plot(pxs[0],fits3[0],c='k')
plt.plot(pxs[1],lists[1],marker='o',ls='')
plt.plot(pxs[1],fits3[1],c='k')
plt.show()
# Out:
# [ 4.33988410e-03 -4.86163163e-01  2.41559329e+01  5.21995347e+02
#   9.35368050e+04 -5.80141295e+02  1.09341482e+00  1.01283686e+00]
# [ 1.37956125e-02 -1.17694002e+00  4.66051102e+01  2.69540467e+02
#   8.84613348e+04 -4.59830568e+02  1.39253490e+00 -7.00439383e-01]
# [ 8.83902379e-03 -9.44260927e-01  4.63288877e+01  1.12530265e+02
#   8.79571534e+04  3.28048166e+02  1.39977592e+00 -1.62477619e+00]
# [ 2.44367823e-03 -5.72471113e-01  4.47244301e+01 -1.69779574e+02
#   8.98354347e+04 -2.85918731e+02  1.40479449e+00  9.12789493e-02]
# [ 1.42874545e-03 -6.90182183e-01  5.02772670e+01 -1.79295357e+02
#   9.13283350e+04  4.89627890e+02  1.39114502e+00  1.16346773e-01]
# [-4.34647981e-03 -4.37116195e-01  4.60114948e+01 -1.32365723e+02
#   9.16702344e+04 -3.88479992e+02  1.41318841e+00 -1.83117840e+00]
# [ 7.87564930e-03 -1.03052697e+00  5.78622554e+01 -3.62409578e+02
#   9.24089306e+04 -3.85270473e+02  1.39651589e+00  3.52936216e+00]
# [ 3.10367945e-02 -2.09909985e+00  7.04076424e+01 -3.40280002e+02
#   9.20875329e+04  3.24834466e+02  1.39744609e+00 -3.64068073e-01]
# [ 6.19253700e-02 -3.93938375e+00  1.09429235e+02 -7.34897697e+02
#   9.36775692e+04  1.81036659e+02  1.43036894e+00 -2.07636291e+00]
# [ 3.99955962e-02 -1.99889273e+00  5.52681926e+01 -6.16614598e+01
#   8.98513803e+04 -1.94628598e+02  1.41200268e+00 -2.19462282e+00]
# [ 9.05153061e-02 -4.80791184e+00  1.07979999e+02 -5.57092996e+02
#   8.84720760e+04  1.52714840e+02  1.40139710e+00 -1.79775864e+00]
# [67.496516273, 67.68073056783669, 67.33061946311467, 67.09008355232969, 67.74835009644428, 66.69158841980268, 67.48779598828983, 67.44287334342309, 65.89053857849854, 66.7475925938501, 67.25272924178331]

# %%
fields = np.array([0.0,20.0,40.0,60.0,80.0,100.0,120.0,140.0,160.0,180.0,200.0])

pm, array = curve_fit(line, fields[4:11], As2[4:11], p0=[1.0,1.0], sigma = elist[4:11], absolute_sigma=True, maxfev=10000)

linefit2 = line(fields[4:11], *pm)

pm, array = curve_fit(line, fields[0:4], As2[0:4], p0=[1.0,1.0], sigma = elist[0:4], absolute_sigma=True, maxfev=10000)

linefit1 = line(fields[0:4], *pm)

pm, array = curve_fit(line, fields, lams2, p0=[1.0,1.0], sigma = elist2, absolute_sigma=True, maxfev=10000)

linefit3 = line(fields, *pm)

# %%
# %matplotlib notebook
fields = [0,20,40,60,80,100,120,140,160,180,200]

start = 0.2
stop = 0.8
number_of_lines = len(lists)
cm_subsection = np.linspace(start, stop, number_of_lines) 
colors = [ plt.cm.plasma(x) for x in cm_subsection ]

plt.figure(figsize=(8,7))

'''
ax1=plt.subplot2grid((2,2),(0,0), rowspan=1,colspan=1)
for i in np.arange(0,len(lists),1):
    #plt.plot(pxs[i],lists[i]/1000+i*5,color=colors[i],marker='o',markeredgecolor='k')
    plt.plot(pxs[i],fits3[i]/1000+i*5,color='k')
    plt.errorbar(pxs[i],lists[i]/1000+i*5, yerr = errs[i]/1000,color='k')
'''  
ax2=plt.subplot2grid((2,2),(0,0), rowspan=2,colspan=1)
for i in np.arange(0,len(lists),1):
    plt.plot(lpxs[i]*15,lfits3[i]/1000+i*1.5-lfits1[i]/1000,color='k',zorder=1)
    plt.errorbar(pxs[i]*15,lists[i]/1000+i*1.5-fits1[i]/1000, yerr = errs[i]/1000,color='k',zorder=2,ls='')
    plt.plot(pxs[i]*15,lists[i]/1000+i*1.5-fits1[i]/1000,color=colors[i],marker='o',markeredgecolor='k',zorder=3,ls='')
plt.xlim((0,300))
plt.yticks([])
plt.ylabel('Norm. Intensity (arb. units)')
plt.xlabel('$x$ (nm)')


ax2=plt.subplot2grid((2,2),(0,1), rowspan=1,colspan=1)
plt.errorbar(fields,As2/max(As2), yerr = elist/max(As2),color='k',ls='',zorder=2)
plt.plot(fields,As2/max(As2),marker='o',color=colors[5],markeredgecolor='k',ls='',zorder=3)
plt.plot(fields[4:11],linefit2/max(As2),color=colors[5],zorder=1)
plt.plot(fields[0:4],linefit1/max(As2),color=colors[5],zorder=1)

plt.plot((70,70),(0,1.2),color='dimgrey',ls='--',lw=1)

plt.ylim((0,1.2))
plt.ylabel('Norm. Contrast (arb. units)')
plt.xlabel('$B$ (mT)')

ax3=plt.subplot2grid((2,2),(1,1), rowspan=1,colspan=1)
plt.errorbar(fields,lams2, yerr = elist2,color='k',ls='',zorder=2)
plt.plot(fields,linefit3,color=colors[5])
plt.plot(fields[:],lams2[:],marker='o',color=colors[5],markeredgecolor='k',ls='',zorder=3)
plt.ylim([60,80])
plt.tight_layout()
plt.show() 
plt.savefig('cone_angle.png',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
def sine(values, A, w, p, bg):
    return A*np.sin(values*w+p)+bg

def cubic(values,k,m,c):
    return k*values**2+m*values+c

def both(values, k, m, c, A, w, p):
    return k*values**2+m*values+c+A*np.sin(values*w+p)

def line(values, m, c):
    return values*m + c

# %%
#Load tube scan

scans = [21,22,23,27,28,34,38,39]
t_lists = []
t_pxs = []
t_errs = []

for i in np.arange(0,len(scans),1):
    with open('Exp_again/tube_'+str(scans[i])+'.csv', 'r') as f:
        tube_data = list(csv.reader(f, delimiter=','))
    tube_data = np.array(tube_data[1:], dtype=np.float)
    tube = tube_data[:,1]

    tube_t_pxs = np.array(tube_data[:,0], dtype=np.float)
    err = np.sqrt(tube)

    t_lists.append(tube)
    t_pxs.append(tube_t_pxs)
    t_errs.append(err)

# %%
#Fitting line scan

pms_t = []
arrays_t = []
fits_t = []
lfits_t = []
lpxs_t = []

for i in np.arange(0,len(t_lists),1):
    pm, array = curve_fit(cubic, t_pxs[i], t_lists[i], p0=(1,1,9000), sigma = t_errs[i], absolute_sigma=True, maxfev=10000)
    fit = cubic(t_pxs[i],*pm)
    lpx = np.linspace(0,len(t_pxs[i])-1,1000)
    lpxs_t.append(lpx)
    lfit = cubic(lpx,*pm)
    pms_t.append(pm)
    arrays_t.append(array)
    fits_t.append(fit)
    lfits_t.append(lfit)

# %%
# %matplotlib notebook

start = 0.2
stop = 0.8
number_of_lines = len(lists)
cm_subsection = np.linspace(start, stop, number_of_lines) 
colors = [ plt.cm.plasma(x) for x in cm_subsection ]

plt.figure(figsize=(6,8))
for i in np.arange(0,len(t_lists),1):
    plt.plot(t_pxs[i],t_lists[i]+10000*i,marker='o',color=colors[i],ls='')
    plt.plot(lpxs_t[i],lfits_t[i]+10000*i,marker='',color=colors[i],ls='-')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
pms2_t = []
arrays2_t = []
fits2_t = []

p0s = ([1.80815850e+03, 9.07233762e-01, -1.68441779e+00,0])

lens2_t = []
As2_t = []

for i in np.arange(0,len(t_lists),1):
    pm, array = curve_fit(sine, t_pxs[i], t_lists[i]-fits[i], p0=p0s, absolute_sigma=True, maxfev=10000)
    fit = sine(pxs[i],*pm)
    pms2_t.append(pm)
    arrays2_t.append(array)
    fits2_t.append(fit)
    lens2_t.append(pm[1])
    As2_t.append(abs(pm[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-03e9d16872bc> in <module>
#       9
#      10 for i in np.arange(0,len(t_lists),1):
# ---> 11     pm, array = curve_fit(sine, t_pxs[i], t_lists[i]-fits[i], p0=p0s, absolute_sigma=True, maxfev=10000)
#      12     fit = sine(pxs[i],*pm)
#      13     pms2_t.append(pm)
#
# NameError: name 'fits' is not defined

# %%
pms3_t = []
arrays3_t = []
fits3_t = []
lfits3_t = []
lens2_t = []
As2_t = []
lams2_t = []

elist_t = []
elist2_t = []


p0s = ([8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00],
      [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00])

p0s = []

pm = [8.20e+01, -8.47e+02, 9.40e+04, -3.92e+02,  1.41e+00, -1.26e+00]

for i in np.arange(0,len(t_lists),1):
    p0s.append(np.array([*pms_t[i],*pms2_t[i][0:-1]]))

for i in np.arange(0,len(t_lists),1):
    pm, array = curve_fit(both, t_pxs[i], t_lists[i], p0=p0s[i], sigma = t_errs[i], absolute_sigma=True, maxfev=10000)
    fit = both(t_pxs[i],*pm)
    lfit = both(lpxs_t[i],*pm)
    print(pm)
    pms3_t.append(pm)
    arrays3_t.append(array)
    fits3_t.append(fit)
    lfits3_t.append(lfit)
    lens2_t.append(20*np.pi/pm[4])
    As2_t.append(abs(pm[3]))
    lams2_t.append(20*np.pi/pm[4])
  
    elist_t.append(np.sqrt(np.diag(array))[3])
    elist2_t.append(20*np.sqrt(np.diag(array))[4])


#lams2[0] = 67.496516273
#print(lams2)


#print(elist)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-191a6d36defc> in <module>
#      28
#      29 for i in np.arange(0,len(t_lists),1):
# ---> 30     p0s.append(np.array([*pms_t[i],*pms2_t[i][0:-1]]))
#      31
#      32 for i in np.arange(0,len(t_lists),1):
#
# IndexError: list index out of range

# %%
# %matplotlib notebook
plt.figure(figsize=(8,7))

fs = np.array([35,37,40,50,70,80,90,100])

ax1=plt.subplot2grid((2,2),(0,0), rowspan=2,colspan=1)

for i in np.arange(0,len(t_lists),1):
    plt.plot(t_pxs[i],t_lists[i]+10000*i,marker='o',ls='',color=colors[i])
    plt.errorbar(t_pxs[i],t_lists[i]+10000*i,yerr=t_errs[i],marker='',ls='',color='k',)
    plt.plot(t_pxs[i],fits3_t[i]+10000*i,c='k')
    
ax2=plt.subplot2grid((2,2),(0,1), rowspan=1,colspan=1)

plt.errorbar(fs,As2_t/max(As2_t), yerr = elist_t/max(As2_t),color='k',ls='',zorder=2)
plt.plot(fs,As2_t/max(As2_t),marker='o',color=colors[5],markeredgecolor='k',ls='',zorder=3)

plt.errorbar(fields,As2/max(As2), yerr = elist/max(As2),color='k',ls='',zorder=2)
plt.plot(fields,As2/max(As2),marker='o',color=colors[1],markeredgecolor='k',ls='',zorder=3)
plt.plot(fields[4:11],linefit2/max(As2),color=colors[1],zorder=1)
plt.plot(fields[0:4],linefit1/max(As2),color=colors[1],zorder=1)


ax3=plt.subplot2grid((2,2),(1,1), rowspan=1,colspan=1)

plt.errorbar(fs,lams2_t, yerr = elist2_t,color='k',ls='',zorder=2)
plt.plot(fs,lams2_t,marker='o',color=colors[5],markeredgecolor='k',ls='',zorder=3)

plt.errorbar(fields,lams2, yerr = elist2,color='k',ls='',zorder=2)
plt.plot(fields,linefit3,color=colors[1])
plt.plot(fields[:],lams2[:],marker='o',color=colors[1],markeredgecolor='k',ls='',zorder=3)
#plt.ylim([60,80])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-ddc1d2901368> in <module>
#       9     plt.plot(t_pxs[i],t_lists[i]+10000*i,marker='o',ls='',color=colors[i])
#      10     plt.errorbar(t_pxs[i],t_lists[i]+10000*i,yerr=t_errs[i],marker='',ls='',color='k',)
# ---> 11     plt.plot(t_pxs[i],fits3_t[i]+10000*i,c='k')
#      12
#      13 ax2=plt.subplot2grid((2,2),(0,1), rowspan=1,colspan=1)
#
# IndexError: list index out of range

# %%
def sine(values, A, w, p, bg):
    return A*np.sin(values*w+p)+bg

def cubic(values,k,m,c):
    return k*values**2+m*values+c

def both(values, k, m, c, A, w, p):
    return k*values**2+m*values+c+A*np.sin(values*w+p)

def line(values, m, c):
    return values*m + c

def peak(th, k, m, Sbg, S0, th0, dth0, S1, th1, dth1, S2, th2, dth2):
    #Function calculates signal
    return Sbg+k*th**2+m*th+S0/(1+4*(((th-th0)/dth0)**2))+S1/(1+4*(((th-th1)/dth1)**2))+S2/(1+4*(((th-th2)/dth2)**2))

# %%
#Load tube scan

scans = [21,22,23,27,28,34,38,39]
t_lists = []
t_pxs = []
t_errs = []

for i in np.arange(0,len(scans),1):
    with open('Exp_again/tube_'+str(scans[i])+'.csv', 'r') as f:
        tube_data = list(csv.reader(f, delimiter=','))
    tube_data = np.array(tube_data[1:], dtype=np.float)
    tube = tube_data[:,1]

    tube_t_pxs = np.array(tube_data[:,0], dtype=np.float)
    err = np.sqrt(tube)

    t_lists.append(tube)
    t_pxs.append(tube_t_pxs)
    t_errs.append(err)

# %%
p0s = [*pms_t[0], 2.91365407e+03, 3.52342995e+00, 1.56142021e+00, 4.74731814e+03, 1.04742733e+01, 2.18216547e+00, 3000,17,3.5]

p_pms = []
p_fits = []
p_lpxs = []

for i in np.arange(0,5,1):
    pm, array = curve_fit(peak, t_pxs[i], t_lists[i], p0=p0s, sigma = t_errs[i], absolute_sigma=True, maxfev=10000)
    
    lpxs_t = np.linspace(0,len(t_lists[i]),100)
    fit = peak(lpxs_t,*pm)
    
    p0s = pm
    p_pms.append(pm)
    p_fits.append(fit)
    p_lpxs.append(lpxs_t)

print(pm)

p0s = [1.94478453e+02, -3.42867549e+03,  2.32620207e+05,  1.20581199e+04,
  2.52162328e+00,  8.82302872e+00,  1.88740033e+04,  8.23705446e+00,
  8.35797560e+00,  1.75183243e+04,  1.56933967e+01,  1.01331294e+01]
i = 5    
pm, array = curve_fit(peak, t_pxs[i], t_lists[i], p0=p0s, sigma = t_errs[i], absolute_sigma=True, maxfev=10000)
lpxs_t = np.linspace(0,len(t_lists[i]),100)
fit = peak(lpxs_t, *pm)
p_fits.append(fit)
p_lpxs.append(lpxs_t)
p_pms.append(pm)
p0s = pm


for i in np.arange(6,8,1):
    pm, array = curve_fit(peak, t_pxs[i], t_lists[i], p0=p0s, sigma = t_errs[i], absolute_sigma=True, maxfev=10000)
    
    lpxs_t = np.linspace(0,len(t_lists[i]),100)
    fit = peak(lpxs_t,*pm)
    
    p0s = pm
    p_pms.append(pm)
    p_fits.append(fit)
    p_lpxs.append(lpxs_t)
# Out:
# [ 2.04478453e+02 -3.42867549e+03  2.32620207e+05  1.20581199e+04
#   2.52162328e+00  7.82302872e+00  1.88740033e+04  8.23705446e+00
#   8.35797560e+00  1.75183243e+04  1.46933967e+01  1.01331294e+01]

# %%
plt.figure()
for i in np.arange(0,8,1):
    plt.plot(t_pxs[i], t_lists[i]+7000*i,marker='o',ls='',color=colors[i])
    plt.plot(p_lpxs[i], p_fits[i]+7000*i, marker='',ls='-',color='k')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
### Calculate Distances ###
plams = []
for i in np.arange(0,8,1):
    print(i)
    d1 = p_pms[i][4]
    d2 = p_pms[i][7]
    d3 = p_pms[i][10]
    width = np.average(-10*(d2-d3))
    print(width)
    plams.append(width)
# Out:
# 0
# 70.46137075145307
# 1
# 65.41489908631668
# 2
# 67.57182634882804
# 3
# 61.09632820070999
# 4
# 64.56342262711328
# 5
# 61.28272554064148
# 6
# 69.67325206055006
# 7
# 112.28993934113915

# %%
# %matplotlib notebook
plt.figure(figsize=(8,7))

fs = np.array([35,37,40,50,70,80,90,100])

ax1=plt.subplot2grid((2,2),(0,0), rowspan=2,colspan=1)

for i in np.arange(0,len(t_lists),1):
    plt.plot(t_pxs[i],t_lists[i]+10000*i,marker='o',ls='',color=colors[i])
    plt.errorbar(t_pxs[i],t_lists[i]+10000*i,yerr=t_errs[i],marker='',ls='',color='k',)
    plt.plot(t_pxs[i],fits3_t[i]+10000*i,c='k')
    
ax2=plt.subplot2grid((2,2),(0,1), rowspan=1,colspan=1)

plt.errorbar(fs,As2_t/max(As2_t), yerr = elist_t/max(As2_t),color='k',ls='',zorder=2)
plt.plot(fs,As2_t/max(As2_t),marker='o',color=colors[5],markeredgecolor='k',ls='',zorder=3)

plt.errorbar(fields,As2/max(As2), yerr = elist/max(As2),color='k',ls='',zorder=2)
plt.plot(fields,As2/max(As2),marker='o',color=colors[1],markeredgecolor='k',ls='',zorder=3)
plt.plot(fields[4:11],linefit2/max(As2),color=colors[1],zorder=1)
plt.plot(fields[0:4],linefit1/max(As2),color=colors[1],zorder=1)


ax3=plt.subplot2grid((2,2),(1,1), rowspan=1,colspan=1)

#plt.errorbar(fs,lams2_t, yerr = elist2_t,color='k',ls='',zorder=2)
plt.plot(fs,plams,marker='o',color=colors[5],markeredgecolor='k',ls='',zorder=3)

plt.errorbar(fields,lams2, yerr = elist2,color='k',ls='',zorder=2)
plt.plot(fields,linefit3,color=colors[1])
plt.plot(fields[:],lams2[:],marker='o',color=colors[1],markeredgecolor='k',ls='',zorder=3)
#plt.ylim([60,80])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-d8e2284eec72> in <module>
#       9     plt.plot(t_pxs[i],t_lists[i]+10000*i,marker='o',ls='',color=colors[i])
#      10     plt.errorbar(t_pxs[i],t_lists[i]+10000*i,yerr=t_errs[i],marker='',ls='',color='k',)
# ---> 11     plt.plot(t_pxs[i],fits3_t[i]+10000*i,c='k')
#      12
#      13 ax2=plt.subplot2grid((2,2),(0,1), rowspan=1,colspan=1)
#
# IndexError: list index out of range
